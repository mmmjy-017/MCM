# %%
# 以下代码是导入这个数据集
# 注意data返回的是一个字典
from sklearn.datasets import load_iris
data = load_iris()

# %%
x = data['data']
y = data['target']

# %%
x = x[50:]
y = y[50:]

# %%
## 数据集划分
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#导入我们的决策树模型（分类）
from sklearn.tree import DecisionTreeClassifier

#实例化模型
model = DecisionTreeClassifier(max_depth = 3)

# %%
#训练模型
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#预测数据
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
#准确率
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train_pred,y_train)
# Out:
# 0.9875

# %%
accuracy_score(y_test_pred,y_test)
# Out:
# 0.75

# %%
# 以下代码是导入这个数据集
# 注意data返回的是一个字典
from sklearn.datasets import load_boston
data = load_boston()

# %%
# 查看data
data.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
X = data['data']
y = data['target']

# %%
# 划分训练集和测试集
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
#导入我们的决策树模型（回归）
from sklearn.tree import DecisionTreeRegressor

#实例化模型
model = DecisionTreeRegressor(max_depth = 5,max_leaf_nodes = 4)

# %%
#训练模型
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_leaf_nodes=4)

# %%
#预测数据
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
y_train_pred
# Out:
# array([22.8955    , 38.0296875 , 22.8955    , 14.93407407, 14.93407407,
#        14.93407407, 22.8955    , 45.58      , 14.93407407, 14.93407407,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        22.8955    , 14.93407407, 22.8955    , 22.8955    , 14.93407407,
#        22.8955    , 22.8955    , 22.8955    , 38.0296875 , 22.8955    ,
#        22.8955    , 38.0296875 , 14.93407407, 38.0296875 , 22.8955    ,
#        14.93407407, 22.8955    , 22.8955    , 22.8955    , 38.0296875 ,
#        22.8955    , 14.93407407, 38.0296875 , 22.8955    , 22.8955    ,
#        14.93407407, 22.8955    , 22.8955    , 38.0296875 , 22.8955    ,
#        38.0296875 , 38.0296875 , 38.0296875 , 22.8955    , 38.0296875 ,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        14.93407407, 14.93407407, 22.8955    , 22.8955    , 22.8955    ,
#        22.8955    , 22.8955    , 22.8955    , 38.0296875 , 14.93407407,
#        22.8955    , 14.93407407, 22.8955    , 22.8955    , 14.93407407,
#        14.93407407, 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 14.93407407, 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 14.93407407, 22.8955    , 14.93407407, 22.8955    ,
#        38.0296875 , 22.8955    , 14.93407407, 14.93407407, 14.93407407,
#        38.0296875 , 22.8955    , 14.93407407, 14.93407407, 38.0296875 ,
#        22.8955    , 14.93407407, 22.8955    , 22.8955    , 14.93407407,
#        14.93407407, 22.8955    , 14.93407407, 22.8955    , 38.0296875 ,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        38.0296875 , 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        38.0296875 , 14.93407407, 22.8955    , 14.93407407, 22.8955    ,
#        14.93407407, 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 14.93407407, 22.8955    , 38.0296875 , 14.93407407,
#        14.93407407, 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        14.93407407, 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        14.93407407, 38.0296875 , 45.58      , 22.8955    , 22.8955    ,
#        14.93407407, 14.93407407, 45.58      , 14.93407407, 22.8955    ,
#        22.8955    , 38.0296875 , 38.0296875 , 14.93407407, 14.93407407,
#        14.93407407, 22.8955    , 14.93407407, 14.93407407, 22.8955    ,
#        22.8955    , 38.0296875 , 14.93407407, 22.8955    , 38.0296875 ,
#        22.8955    , 14.93407407, 22.8955    , 22.8955    , 14.93407407,
#        14.93407407, 14.93407407, 38.0296875 , 38.0296875 , 14.93407407,
#        22.8955    , 38.0296875 , 22.8955    , 14.93407407, 22.8955    ,
#        38.0296875 , 14.93407407, 22.8955    , 22.8955    , 38.0296875 ,
#        22.8955    , 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 22.8955    , 22.8955    , 14.93407407, 14.93407407,
#        22.8955    , 38.0296875 , 14.93407407, 22.8955    , 14.93407407,
#        38.0296875 , 22.8955    , 22.8955    , 38.0296875 , 14.93407407,
#        14.93407407, 38.0296875 , 22.8955    , 22.8955    , 14.93407407,
#        14.93407407, 22.8955    , 38.0296875 , 38.0296875 , 22.8955    ,
#        22.8955    , 22.8955    , 14.93407407, 38.0296875 , 22.8955    ,
#        38.0296875 , 14.93407407, 38.0296875 , 22.8955    , 38.0296875 ,
#        14.93407407, 14.93407407, 14.93407407, 38.0296875 , 22.8955    ,
#        14.93407407, 38.0296875 , 14.93407407, 22.8955    , 14.93407407,
#        38.0296875 , 14.93407407, 22.8955    , 22.8955    , 22.8955    ,
#        14.93407407, 14.93407407, 14.93407407, 22.8955    , 22.8955    ,
#        38.0296875 , 38.0296875 , 22.8955    , 14.93407407, 22.8955    ,
#        14.93407407, 22.8955    , 22.8955    , 14.93407407, 14.93407407,
#        22.8955    , 14.93407407, 22.8955    , 38.0296875 , 14.93407407,
#        14.93407407, 22.8955    , 22.8955    , 14.93407407, 14.93407407,
#        14.93407407, 14.93407407, 38.0296875 , 14.93407407, 14.93407407,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    , 14.93407407,
#        22.8955    , 22.8955    , 14.93407407, 38.0296875 , 22.8955    ,
#        22.8955    , 14.93407407, 14.93407407, 22.8955    , 14.93407407,
#        14.93407407, 38.0296875 , 14.93407407, 14.93407407, 22.8955    ,
#        22.8955    , 22.8955    , 22.8955    , 38.0296875 , 38.0296875 ,
#        38.0296875 , 22.8955    , 22.8955    , 14.93407407, 22.8955    ,
#        22.8955    , 22.8955    , 22.8955    , 14.93407407, 14.93407407,
#        22.8955    , 14.93407407, 14.93407407, 22.8955    , 22.8955    ,
#        14.93407407, 22.8955    , 22.8955    , 14.93407407, 14.93407407,
#        14.93407407, 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        14.93407407, 22.8955    , 45.58      , 14.93407407, 14.93407407,
#        14.93407407, 22.8955    , 22.8955    , 38.0296875 , 22.8955    ,
#        38.0296875 , 22.8955    , 14.93407407, 14.93407407, 14.93407407,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    , 22.8955    ,
#        14.93407407, 38.0296875 , 22.8955    , 22.8955    , 22.8955    ,
#        38.0296875 , 22.8955    , 22.8955    , 38.0296875 , 38.0296875 ,
#        14.93407407, 14.93407407, 38.0296875 , 14.93407407, 22.8955    ,
#        22.8955    , 22.8955    , 14.93407407, 14.93407407, 22.8955    ,
#        22.8955    , 14.93407407, 38.0296875 , 38.0296875 , 22.8955    ,
#        22.8955    , 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 22.8955    , 22.8955    , 38.0296875 , 14.93407407,
#        22.8955    , 14.93407407, 38.0296875 , 22.8955    , 14.93407407,
#        22.8955    , 14.93407407, 38.0296875 , 14.93407407, 14.93407407,
#        22.8955    , 22.8955    , 14.93407407, 22.8955    , 22.8955    ,
#        22.8955    , 14.93407407, 45.58      , 38.0296875 , 22.8955    ,
#        22.8955    , 14.93407407, 22.8955    , 14.93407407, 14.93407407,
#        22.8955    , 22.8955    , 22.8955    , 22.8955    ])

# %%
y_train
# Out:
# array([26.6, 50. , 20.6, 15.1, 17.1, 11.3, 24.4, 27.9, 15.6, 14.1, 20.1,
#        27.5, 17.1, 23.4, 23.2, 19.3, 13.6, 23.7, 24. , 12.7, 15. , 25. ,
#        24.5, 50. , 24.6, 22.9, 37.9, 15.7, 43.5, 19.6, 23.1, 23.8, 23.1,
#        26.6, 30.3, 22.5, 14.3, 21.9, 20.4, 17.5, 19.9, 22.6, 19. , 37.6,
#        18.9, 23.9, 29.8, 50. , 24.8, 35.4, 28.6, 25. , 22.9, 22.2, 24.3,
#        18.9, 17.5, 20.9, 20.5, 25. , 19.5, 21.7, 25. , 50. , 14.9, 23.8,
#        16.4, 27.1, 18.9, 17.2, 17.7, 17.6, 12.7, 28. , 27.5, 29. , 15.2,
#        14.4, 20.4, 21.4, 32. , 17.8, 25. ,  8.4, 22.8, 36.1, 19.3, 27.1,
#        19.5,  8.3, 41.3, 25. , 16. , 18.8, 33.1, 25.2, 13.4, 29.9, 22.8,
#        15.4, 20. , 32.4, 10.9, 28.2, 45.4, 19.8, 28.4, 31.1, 25. , 15.3,
#        33.4, 28.7,  8.4, 20.6, 21.8, 35.2, 19.3, 21.1, 16.6, 18.5,  9.6,
#        23. , 10.2, 23.1, 21.2, 20.6, 10.5, 23.3, 29.6, 13.8, 13.8, 20. ,
#        22. , 21.5, 20.3, 18.4, 19.9, 14.5, 22.7, 23.9, 14.1, 39.8, 50. ,
#        29.4, 29.1, 20.1, 12. , 50. , 19.1, 24.7, 20.8, 33. , 50. , 13.6,
#        27.5, 14.5, 16.2, 11.8, 13.1, 23.4, 21.6, 10.4, 14.8, 24.1, 35.4,
#        19.6, 16.8, 19.1, 19.2, 17. , 11.7,  7.4, 37. , 29. , 15.4, 24.8,
#        34.6, 20.6, 16.7, 24.7, 43.1,  8.1, 22.2, 20.1, 23.6, 24.8, 23.7,
#         9.5, 22.2, 20.4, 24.5, 20.2, 32. , 13.8, 14.5, 22. , 46. , 12.3,
#        28.4, 13.5, 50. , 23.6, 22. , 34.9, 13.3, 13.4, 48.8, 23.1, 24.1,
#        19.7, 18.8, 25.1, 31.7, 44. , 19.6, 22.9, 22.3,  5. , 50. , 19.9,
#        50. , 11.8, 28.7, 21.2, 50. ,  8.5, 17.5, 13.1, 46.7, 26.5, 13.3,
#        42.3, 23.1, 20.7, 18.3, 48.3, 10.4, 20.1, 29.1, 24.3, 18.5, 21.4,
#        13.9, 19.4, 30.1, 50. , 50. , 23.1, 19.5, 21.4, 20.3, 18.5, 22. ,
#        11. ,  7.5, 20.8, 10.2, 23. , 33.3, 17.8, 21.5, 22. , 20.2, 20. ,
#        21.7, 13.8, 14.9, 15. , 17.3,  9.7, 29.8, 21. , 24.5, 26.6, 17.4,
#        23.2, 26.4, 22.4, 36. , 30.1, 19.8, 13.1, 16.6, 22.2, 14.3, 17.9,
#        44.8, 17.4, 23.2, 28.1, 22.5, 22.9, 31.2, 36.4, 31.6, 37.3, 18.7,
#        20.3, 15.6, 22.8, 30.8, 23. , 24.8, 14.1, 13.4, 21.7, 12.5, 19.4,
#        24.4, 11.9,  8.3, 22. , 20.8,  8.8, 13.1,  7.2, 21.1, 10.9, 21.8,
#        22.4, 15.6, 20.6, 50. , 17.8,  7.2, 14.6, 21. , 20.3, 33.8, 26.4,
#        48.5, 22. , 13.5, 16.5,  8.7, 20.1, 24.6, 24. , 18.6, 18.4, 13.9,
#        32.9, 18.2, 22.6, 29.6, 34.9, 21.7, 23.3, 36.5, 33.4, 17.8, 16.1,
#        41.7, 13.4, 21.2, 22.7, 23.5, 15.2, 13.2, 19.2, 17.4, 11.5, 33.2,
#        32.7, 21. , 23.2, 21.6, 10.2, 19.5, 16.1, 19.7, 22.6, 23.9, 36.2,
#        15.6, 33.1, 13. , 38.7, 28.5, 10.5, 35.1, 14.2, 43.8, 21.7, 19.8,
#        24.4, 20.5,  7. , 18.5, 25.3, 22.2, 15.6, 50. , 31.5, 27.5, 20. ,
#        19.4, 18.2, 13.3, 19.1, 18.3, 23.9, 19.4, 24.7])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train_pred,y_train)
# Out:
# 26.251165353983314

# %%
mean_squared_error(y_test_pred,y_test)
# Out:
# 29.282491029435946

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train_pred,y_train)
# Out:
# 0.5887515654651139

# %%
r2_score(y_test_pred,y_test)
# Out:
# 0.4143843086801863
